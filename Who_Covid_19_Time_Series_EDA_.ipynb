# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharthaborgohain/Covid-19-Live-case-study/blob/main/Who_Covid_19_Time_Series_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as pt, seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("WHO-COVID-19-global-data.csv")
df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202635 entries, 0 to 202634
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      202635 non-null  object
#  1   Country_code       201780 non-null  object
#  2   Country            202635 non-null  object
#  3   WHO_region         202635 non-null  object
#  4   New_cases          202635 non-null  int64
#  5   Cumulative_cases   202635 non-null  int64
#  6   New_deaths         202635 non-null  int64
#  7   Cumulative_deaths  202635 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 12.4+ MB

# %%
df["Date_reported"]=pd.to_datetime(df["Date_reported"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202635 entries, 0 to 202634
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      202635 non-null  datetime64[ns]
#  1   Country_code       201780 non-null  object
#  2   Country            202635 non-null  object
#  3   WHO_region         202635 non-null  object
#  4   New_cases          202635 non-null  int64
#  5   Cumulative_cases   202635 non-null  int64
#  6   New_deaths         202635 non-null  int64
#  7   Cumulative_deaths  202635 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 12.4+ MB

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date_reported",y="New_cases", data=df)
# Out:
# <AxesSubplot:xlabel='Date_reported', ylabel='New_cases'>

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date_reported",y="Cumulative_cases", data=df)
# Out:
# <AxesSubplot:xlabel='Date_reported', ylabel='Cumulative_cases'>

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date_reported",y="New_deaths", data=df)
# Out:
# <AxesSubplot:xlabel='Date_reported', ylabel='New_deaths'>

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date_reported",y="Cumulative_deaths", data=df)
# Out:
# <AxesSubplot:xlabel='Date_reported', ylabel='Cumulative_deaths'>

# %%
df.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  2.026350e+05      2.026350e+05  202635.000000      202635.000000
# mean   2.536363e+03      6.345066e+05      30.842155       11864.956582
# std    1.664276e+04      3.369870e+06     163.257199       55104.264356
# min   -3.295200e+04      0.000000e+00   -2448.000000           0.000000
# 25%    0.000000e+00      2.030000e+02       0.000000           2.000000
# 50%    2.400000e+01      1.175800e+04       0.000000         152.000000
# 75%    5.080000e+02      1.665705e+05       6.000000        2787.500000
# max    1.252940e+06      8.085484e+07   11447.000000      989435.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
g=df.groupby("WHO_region")

# %%
for i,j in g:
    print(i)
    print(j["Country"].unique())
# Out:
# AFRO
# ['Algeria' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Burundi'
#  'Cabo Verde' 'Cameroon' 'Central African Republic' 'Chad' 'Comoros'
#  'Congo' 'Côte d’Ivoire' 'Democratic Republic of the Congo'
#  'Equatorial Guinea' 'Eritrea' 'Eswatini' 'Ethiopia' 'Gabon' 'Gambia'
#  'Ghana' 'Guinea' 'Guinea-Bissau' 'Kenya' 'Lesotho' 'Liberia' 'Madagascar'
#  'Malawi' 'Mali' 'Mauritania' 'Mauritius' 'Mayotte' 'Mozambique' 'Namibia'
#  'Niger' 'Nigeria' 'Réunion' 'Rwanda' 'Saint Helena'
#  'Sao Tome and Principe' 'Senegal' 'Seychelles' 'Sierra Leone'
#  'South Africa' 'South Sudan' 'Togo' 'Uganda'
#  'United Republic of Tanzania' 'Zambia' 'Zimbabwe']
# AMRO
# ['Anguilla' 'Antigua and Barbuda' 'Argentina' 'Aruba' 'Bahamas' 'Barbados'
#  'Belize' 'Bermuda' 'Bolivia (Plurinational State of)' 'Bonaire' 'Brazil'
#  'British Virgin Islands' 'Canada' 'Cayman Islands' 'Chile' 'Colombia'
#  'Costa Rica' 'Cuba' 'Curaçao' 'Dominica' 'Dominican Republic' 'Ecuador'
# ...

# %%
confirmed=df.groupby("Country").sum()[['New_cases','New_deaths']].reset_index()
confirmed

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-eac3c537-d141-49be-badb-a89decfde448') # Let Mito know which analysis is being run

# Sorted New_deaths in confirmed in descending order
confirmed = confirmed.sort_values(by='New_cases', ascending=False, na_position='last')

  
# MITO CODE END (DO NOT EDIT)

# %%
Death_cwise=confirmed.head(10)
Death_cwise
# Out:
#                       Country  New_cases  New_deaths
# 226  United States of America   80854843      989435
# 96                      India   43094938      524002
# 28                     Brazil   30502501      663759
# 72                     France   28012023      143249
# 78                    Germany   25215210      136339
# 210        The United Kingdom   22102987      175984
# 173        Russian Federation   18216719      376696
# 170         Republic of Korea   17464782       23206
# 103                     Italy   16682626      164179
# 217                    Turkey   15038495       98819

# %%
confirmed1=df.groupby("WHO_region").sum()[['New_cases','New_deaths']].reset_index()
confirmed1=confirmed1.sort_values(by='New_cases', ascending=False, na_position='last')
confirmed1
# Out:
#   WHO_region  New_cases  New_deaths
# 3       EURO  216346110     1994452
# 1       AMRO  153611428     2728205
# 5      SEARO   57921120      786804
# 6       WPRO   55555115      226081
# 2       EMRO   21708991      342369
# 0       AFRO    8812382      171776
# 4      Other        764          13

# %%
plt.figure(figsize=(15,7))
plt.plot(Death_cwise["Country"],Death_cwise["New_deaths"])

# %%
plt.figure(figsize=(15,7))
plt.bar(Death_cwise["Country"],Death_cwise["New_cases"])
# Out:
# <BarContainer object of 10 artists>
